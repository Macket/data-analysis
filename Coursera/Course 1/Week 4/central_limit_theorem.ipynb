# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math
# %matplotlib inline

# %% [markdown]
# # Экспоненциальное распределение

# %% [markdown]
# Плотность распределения
# $f(x) = 0$ при $x < 0$;
# $f(x) = \lambda exp(-\lambda t)$ при $x >= 0$

# %% [markdown]
# Мат. ожидание - $1/\lambda$, дисперсия - $1/\lambda^2$

# %%
lambd = 2.0 # параметр лямбда

# зададим экспоненциально распределенную случайную величину
expon_rv = sts.expon(scale = 1.0/lambd)

# %% [markdown]
# ## Гистограмма и теоретическая плотность

# %%
sample = expon_rv.rvs(1000) # генерируем выборку объема 1000

# теоретическая плотность распределения 
x = np.linspace(0,5,100)
pdf = expon_rv.pdf(x) 
plt.plot(x, pdf, label='theoretical PDF')

# гистограмма
plt.hist(sample, normed=True, label = 'bar chart')

# подписи к осям и легенда
plt.ylabel('$f(x)$ or number of samples')
plt.xlabel('$x$')
plt.legend()

# %% [markdown]
# ## Выборка объема 5

# %% [markdown]
# Параметры нормального распределения: $\mu = 1/\lambda = 0.5$, $\sigma = \sqrt{1/(\lambda^2n)} = 1/(\lambda\sqrt{n}) = 0.5/\sqrt{5}$

# %%
n = 5
averages = []
for k in range(1000):
    sum = 0
    rvs = expon_rv.rvs(n)
    for i in range (n):
        sum = sum + rvs[i]
    averages.append(sum/n)
    
# гистограмма
plt.hist(averages, bins = 20, normed=True, label = 'bar chart')

# нормальное распределение по ЦПТ
mu = 1.0/lambd
sigma = (1.0/lambd)/math.sqrt(n)
norm_rv = sts.norm(loc = mu, scale = sigma)

x = np.linspace(0,2,100)
norm_pdf = norm_rv.pdf(x)
plt.plot(x, norm_pdf, label='theoretical PDF')
plt.ylabel('averages distribution')
plt.xlabel('$x$')
plt.legend()

# %% [markdown]
# ## Выборка объема 50

# %% [markdown]
# Параметры нормального распределения: $\mu = 1/\lambda = 0.5$, $\sigma = \sqrt{1/(\lambda^2n)} = 1/(\lambda\sqrt{n}) = 0.5/\sqrt{50}$

# %%
n = 50
averages = []
for k in range(1000):
    sum = 0
    rvs = expon_rv.rvs(n)
    for i in range (n):
        sum = sum + rvs[i]
    averages.append(sum/n)
    
# гистограмма
plt.hist(averages, bins = 20, normed=True, label = 'bar chart')

# нормальное распределение по ЦПТ
mu = 1.0/lambd
sigma = (1.0/lambd)/math.sqrt(n)
norm_rv = sts.norm(loc = mu, scale = sigma)

x = np.linspace(0,1,100)
norm_pdf = norm_rv.pdf(x)
plt.plot(x, norm_pdf, label='theoretical PDF')
plt.ylabel('averages distribution')
plt.xlabel('$x$')
plt.legend()

# %% [markdown]
# ## Выборка объема 100

# %% [markdown]
# Параметры нормального распределения: $\mu = 1/\lambda = 0.5$, $\sigma = \sqrt{1/(\lambda^2n)} = 1/(\lambda\sqrt{n}) = 0.5/\sqrt{100}$

# %%
n = 100
averages = []
for k in range(1000):
    sum = 0
    rvs = expon_rv.rvs(n)
    for i in range (n):
        sum = sum + rvs[i]
    averages.append(sum/n)
    
# гистограмма
plt.hist(averages, bins = 20, normed=True, label = 'bar chart')

# нормальное распределение по ЦПТ
mu = 1.0/lambd
sigma = (1.0/lambd)/math.sqrt(n)
norm_rv = sts.norm(loc = mu, scale = sigma)

x = np.linspace(0,1,100)
norm_pdf = norm_rv.pdf(x)
plt.plot(x, norm_pdf, label='theoretical PDF')
plt.ylabel('averages distribution')
plt.xlabel('$x$')
plt.legend()

# %% [markdown]
# ## Выборка объема 500

# %% [markdown]
# Параметры нормального распределения: $\mu = 1/\lambda = 0.5$, $\sigma = \sqrt{1/(\lambda^2n)} = 1/(\lambda\sqrt{n}) = 0.5/\sqrt{500}$

# %%
n = 5000
averages = []
for k in range(1000):
    sum = 0
    rvs = expon_rv.rvs(n)
    for i in range (n):
        sum = sum + rvs[i]
    averages.append(sum/n)
    
# гистограмма
plt.hist(averages, bins = 20, normed=True, label = 'bar chart')

# нормальное распределение по ЦПТ
mu = 1.0/lambd
sigma = (1.0/lambd)/math.sqrt(n)
norm_rv = sts.norm(loc = mu, scale = sigma)

x = np.linspace(0.4,0.6,100)
norm_pdf = norm_rv.pdf(x)
plt.plot(x, norm_pdf, label='theoretical PDF')
plt.ylabel('averages distribution')
plt.xlabel('$x$')
plt.legend()

# %% [markdown]
# ## Выводы

# %% [markdown]
# При увеличении $n$ гистограмма становится уже, так как дисперсия обратно пропорциональна корню из $n$.
# Теоретическое нормальное распределение все лучше и лучше аппроксимирует диаграмму с ростом $n$. При $n = 5000$ получается очень близкая аппроксимация.
